# %% [markdown]
# ## Updating Data Exercise
#
# **This exercise uses the `netflix_titles.csv` dataset**

# %%
import pandas as pd

# %%
# read in the netflix_titles.csv dataset.  Make sure to tell pandas to use the correct separator character!
titles = pd.read_csv("data/netflix_titles.csv", sep="|")
titles.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# set the index to be the "show_id" (inplace)
titles.set_index("show_id", inplace=True)
titles.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
# Find the row with the id of s2202 and set its director to "Greg Whiteley"
titles.loc["s2202", ["director"]] = "Greg Whiteley"
titles.loc["s2202"]
# Out:
# type                                                      TV Show
# title                                               Last Chance U
# director                                            Greg Whiteley
# cast            John Franklin III, DJ Law, Buddy Stephens, Bri...
# country                                             United States
# date_added                                          July 28, 2020
# release_year                                                 2020
# rating                                                      TV-MA
# duration                                                5 Seasons
# listed_in                                              Docuseries
# description     In a docuseries set at one of NCAA football's ...
# Name: s2202, dtype: object

# %%
#Update the "duration" of the shows with index s2881 and s3601 to be "GONE TOO SOON"
titles.loc[["s2881", "s3601"], ["duration"]] = "GONE TOO SOON"
titles.loc[["s2881", "s3601"], ["duration"]]
# Out:
#               duration
# show_id
# s2881    GONE TOO SOON
# s3601    GONE TOO SOON

# %%
#rename the release_year column to "release_yr" in place
mapper = {"release_year":"release_yr"}
titles.rename(columns=mapper, inplace=True)
titles.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_yr rating   duration  \
# show_id
# s1       September 25, 2021        2020  PG-13     90 min
# s2       September 24, 2021        2021  TV-MA  2 Seasons
# s3       September 24, 2021        2021  TV-MA   1 Season
# s4       September 24, 2021        2021  TV-MA   1 Season
# s5       September 24, 2021        2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
# Find the show called "Evil"
# Change its index label to s6666 inplace
titles.loc[titles["title"] == "Evil"]
titles.rename(index={"s1907":"s6666"}, inplace=True)
titles.loc[titles["title"] == "Evil"]
# Out:
#             type title director  \
# show_id
# s6666    TV Show  Evil      NaN
#
#                                                       cast        country  \
# show_id
# s6666    Katja Herbers, Mike Colter, Aasif Mandvi, Mich...  United States
#
#               date_added  release_yr rating  duration  listed_in  \
# show_id
# s6666    October 1, 2020        2019  TV-14  1 Season  TV Dramas
#
#                                                description show_id
# show_id
# s6666    A forensic psychologist partners with a Cathol...   s6666

# %%
# In the rating column, please replace all instances of "UR" and "NR" with "No Rating".  Don't do it inplace!
titles["rating"].replace(["UR", "NR"], "No Rating")
titles["rating"].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
# Add a new column "is_fav" and set it to False for all rows
# Update the "is_fav" column to True for the titles in my list of favs (provided below)
favs = ["Young Royals", "Dark", "Big Mouth", "BoJack Horseman", "The Queen's Gambit", "American Vandal", "Russian Doll", "Godless"]
titles["is_fav"] = False
titles.loc[titles["title"].isin(favs), ["is_fav"]] = True
titles["is_fav"].value_counts()
# Out:
# is_fav
# False    8799
# True        8
# Name: count, dtype: int64
